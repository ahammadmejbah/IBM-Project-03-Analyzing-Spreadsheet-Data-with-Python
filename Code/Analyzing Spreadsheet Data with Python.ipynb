# %% [markdown]
# # Analyzing Spreadsheet Data with Python
#
# Estimated time needed: **40 minutes**
#
# We've all been there: sitting at the computer, a cup of coffee in hand, ready to begin the day by tackling a spreadsheet. But once we open it, all we see are numbers upon numbers staring back at us. It can be a little intimidating tackling these numbers, especially with larger spreadsheets, but not to worry! With a few tricks up its sleeve, Python is here to give us a hand!
#
# Interested in learning more about this? Well, you're at the right place!
#
# In this project, we'll be giving you an introduction to the tools that you can use to load spreadsheet data into Python, manipulate it, and write it back to the original file.
#
# ## What You'll Need
#
# You should be familiar with basic concepts of computer programming and the syntaxes of Python programming language. This refers to the concept of list, dictionary, function, class, instance variable, method, etc.
#
# ## What You'll Learn
#
# After completing this guided project, you will be able to:
#
# 1.  Understand the definition of a dataset.
# 2.  Understand the concept of Cell and Sheets in spreadsheet.
# 3.  Load a sheet in an `xlsx` or `xls` file to Python.
# 4.  Perform basic spreadsheet operations such as subsetting, filtering, calculating column mean, median, max and mean, etc.
# 5.  Write to a sheet in an `xlsx` or `xls` file from Python.

# %% [markdown]
# ## Exercise 1: Let's Define Data!
#
# So, let's talk about data. We've been throwing this term around a lot: analyzing *data*, manipulating *data* and writing *data*. What exactly is this "data?
#
# Data is defined as "a collection of numbers, characters, images or other items that provide information of something" (SDM, 3rd CE, Deveaux et al.). In statistical sciences, we store data in files that records *cases* and *variables*:
#
# ![image.png](data\:image/png;base64,...)
#
# As shown in the table above, each entry is called a *case*, and each *case*  includes value(s) for *variable*(s). Cases are often deleted due to missing data.

# %% [markdown]
# ## Exercise 2: Explore a Spreadsheet!
#
# Now that we know the definition of data, we can dive into a spreadsheet!
#
# A spreadsheet is a computer application for organization, analysis, and storage of data in tabular form. `xlsx` and `xls` are the two most popular formats for spreadsheet files. They can be created, opened, and saved using spreadsheet applications such as Microsoft Office Excel and Google Sheets.

# %% [markdown]
# ![image.png](data\:image/png;base64,...)

# %% [markdown]
# An `xlsx` or `xls` file consists of one or more sheets inside. The sheets inside are listed at the bottom left of the Excel window.
#
# In the screenshot above, you can see that this `xlsx` file contains 4 sheets in total named "Facility", "Runway", "Schedules" and "Remarks", respectively. Each sheet is a data table with rows and columns. The small box at a specific row and column inside a data table is called a "Cell". Cells holds the value of a specific value of a case inside this table. It's common practice to use columns for variables and rows for cases.

# %% [markdown]
# ## Exercise 3: Load Data to Python!
#
# Often, we store the data collected in files. `xlsx` and `xls` are two most common formats. To analyze data in the spreadsheet, the first thing we need to do is to load data tables from spreadsheet files to Python.
#
# For the purpose of tutorial, I will provide you with a dataset to work with. You can click [here](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/analysing-spreadsheet-data-with-python/Airport_Data.xlsx) to download the Excel file if you want to open it locally. This Excel file contains some information about airports in Alaska released by the Federal Aviation Association (FAA).
#
# [Pandas](https://pandas.pydata.org/docs/index.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkQuickLabsanalysingspreadsheetdatawithpython28639550-2022-01-01) is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language. It provides convenient ways to work with data tables in Python which we will be utilizing in this guided project.

# %% [markdown]
# First, let's install `openpyxl`. This library will come in handy after we analyze our data as we'll be able to export the results into an Excel file.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 21.0 MB/s eta 0:00:00
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Once you have installed that, please restart your kernel. You can do that by navigating to the button shown below:
#
# ![Restart Your Kernel](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/analysing-spreadsheet-data-with-python/images/Restarting_the_Kernel.png)
#
# After restarting your kernel, continue onward! We can now start analyzing the data.
#
# You can run the following chunk to conveniently get the `xlsx` file ready in lab environment. This code will write the data from the `xlsx` file to a file named `Airport_Data.xlsx`, assuming it doesn't exist.

# %%
import requests
import os

if not os.path.isfile("./Airport_Data.xlsx"):
    r = requests.get("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/analysing-spreadsheet-data-with-python/Airport_Data.xlsx")
    f = open("./Airport_Data.xlsx", mode = "wb+")
    f.write(r.content)
    f.close()

# %% [markdown]
# To load the spreadsheet into Python, we can use pandas's `read_excel()` function. When calling this function, you'll need to specify:
#
# *   The path to the `xls` or `xlsx` file, and
# *   The name of the sheet in which you wish to load into Python.
#
# Both will be passed in format of the string.

# %%
import pandas as pd

df_facilities = pd.read_excel("./Airport_Data.xlsx", sheet_name="Facilities")

# %% [markdown]
# To check what the dataset looks like, we can call the variable containing the data.

# %%
df_facilities
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 0      50009.*A        AIRPORT       'ADK     3/30/2017    AAL           NONE
# 1     50016.1*A        AIRPORT       'AKK     3/30/2017    AAL           NONE
# 2      50017.*A        AIRPORT       'Z13     3/30/2017    AAL           NONE
# 3     50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 4      50020.*A        AIRPORT       'AKI     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 747    50920.*A        AIRPORT       'YAK     3/30/2017    AAL           NONE
# 748   50925.1*A        AIRPORT       'A77     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
# 750    50990.*A        AIRPORT       'L20     3/30/2017    AAL           NONE
#
#     State StateName             County CountyState  ... AirportPositionSource  \
# 0      AK    ALASKA     ALEUTIANS WEST          AK  ...      3RD PARTY SURVEY
# 1      AK    ALASKA      KODIAK ISLAND          AK  ...                  NACO
# 2      AK    ALASKA             BETHEL          AK  ...                 STATE
# 3      AK    ALASKA             BETHEL          AK  ...                   NaN
# 4      AK    ALASKA             BETHEL          AK  ...                 STATE
# ..    ...       ...                ...         ...  ...                   ...
# 746    AK    ALASKA    SKAGWAY-YAKUTAT          AK  ...               FAA-EST
# 747    AK    ALASKA    SKAGWAY-YAKUTAT          AK  ...      3RD PARTY SURVEY
# 748    AK    ALASKA          KUSKOKWIM          AK  ...                   NaN
# 749    AK    ALASKA  KETCHIKAN GATEWAY          AK  ...                   NaN
# 750    AK    ALASKA        UPPER YUKON          AK  ...               FAA-EST
#
#     AirportPositionSourceDate AirportElevationSource  \
# 0                    00:00:00       3RD PARTY SURVEY
# 1                    00:00:00                   NACO
# 2                    00:00:00                  STATE
# 3                         NaN                    NaN
# 4                    00:00:00                  STATE
# ..                        ...                    ...
# 746                  00:00:00                    NaN
# 747                  00:00:00       3RD PARTY SURVEY
# 748                       NaN                    NaN
# 749                       NaN                    NaN
# 750                  00:00:00                    NaN
#
#     AirportElevationSourceDate ContractFuelAvailable TransientStorage  \
# 0                     00:00:00                   NaN              HGR
# 1                     00:00:00                   NaN              NaN
# 2                     00:00:00                   NaN              NaN
# 3                          NaN                   NaN              NaN
# 4                     00:00:00                   NaN              NaN
# ..                         ...                   ...              ...
# 746                        NaN                   NaN              TIE
# 747                   00:00:00                   NaN              HGR
# 748                        NaN                   NaN              NaN
# 749                        NaN                   NaN              NaN
# 750                        NaN                   NaN              NaN
#
#     OtherServices WindIndicator IcaoIdentifier BeaconSchedule2
# 0           CARGO             Y           PADK           SS-SR
# 1             NaN             Y           PAKH             NaN
# 2           CARGO           Y-L            NaN         SEE RMK
# 3             NaN             N            NaN             NaN
# 4           CARGO           Y-L           PFAK           SS-SR
# ..            ...           ...            ...             ...
# 746         CARGO           NaN            NaN             NaN
# 747         CARGO           Y-L           PAYA           SS-SR
# 748         CARGO           NaN            NaN             NaN
# 749         CARGO             N            NaN             NaN
# 750         CARGO             Y            NaN             NaN
#
# [751 rows x 103 columns]

# %% [markdown]
# As shown in the output of the above cell, this data sheet has 751 rows and 103 columns in total. Now you've successfully loaded the data from spreadsheet file into Python.

# %% [markdown]
# ## Exercise 4: Working with Data in Python
#
# Now that you've loaded your data into Python, we can utilize the data science tool Pandas to explore the data and answer a lot of interesting questions!

# %% [markdown]
# ### Question 1: What are the types for aviation facilities in Alaska?
#
# In this dataset, there is a variable called `Type` that records the type of a specific aviation facility. To answer this question, we would need to know what are the unique entries for this variable.
#
# So naturally, we'll need to first extract this column from the entire dataset. The way we extract a column from a dataframe is similar to how we extract a column from a Python dictionary, except that we pass in the column (variable) name instead of key value:

# %%
df_facilities["Type"]
# Out:
# 0            AIRPORT
# 1            AIRPORT
# 2            AIRPORT
# 3      SEAPLANE BASE
# 4            AIRPORT
#            ...
# 746    SEAPLANE BASE
# 747          AIRPORT
# 748          AIRPORT
# 749    SEAPLANE BASE
# 750          AIRPORT
# Name: Type, Length: 751, dtype: object

# %% [markdown]
# The `unique` method of the returned Panda Series will give you the unique entires inside, and in this case, the answer to Question 1.

# %%
df_facilities["Type"].unique()
# Out:
# array(['AIRPORT', 'SEAPLANE BASE', 'HELIPORT'], dtype=object)

# %% [markdown]
# ### Question 2: Provide a table containing the information for all Seaplane Bases in Alaska
#
# In this dataset, there is a variable called `Type` that records what is the type of a specific aviation facility. We want to filter out "Seaplane Base" on variable `Type`. Pandas provides a convenient way to perform element-wise comparison:

# %%
df_facilities["Type"] == "SEAPLANE BASE"
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 746     True
# 747    False
# 748    False
# 749     True
# 750    False
# Name: Type, Length: 751, dtype: bool

# %% [markdown]
# As shown in the result above, the element-wise comparison result is returned in format of a Pandas series, with `True`s and `False`s representing if each case (row) satisfies the condition.
#
# To perform filtering, we can pass in this filtering condition into the original dataframe:

# %%
df_facilities[df_facilities["Type"] == "SEAPLANE BASE"]
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 3     50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 5      50022.*C  SEAPLANE BASE       'KQA     3/30/2017    AAL           NONE
# 8    50027.52*C  SEAPLANE BASE       'Z33     3/30/2017    AAL           NONE
# 15    50031.5*C  SEAPLANE BASE      'AK81     3/30/2017    AAL           NONE
# 24    50035.2*C  SEAPLANE BASE       '3C3     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 725  50877.32*C  SEAPLANE BASE       'MFN     3/30/2017    AAL           NONE
# 734  50877.01*C  SEAPLANE BASE       '2X2     3/30/2017    AAL           NONE
# 737    50905.*C  SEAPLANE BASE       '68A     3/30/2017    AAL           NONE
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
#
#     State StateName               County CountyState  ...  \
# 3      AK    ALASKA               BETHEL          AK  ...
# 5      AK    ALASKA       ALEUTIANS EAST          AK  ...
# 8      AK    ALASKA          BRISTOL BAY          AK  ...
# 15     AK    ALASKA        KODIAK ISLAND          AK  ...
# 24     AK    ALASKA            ANCHORAGE          AK  ...
# ..    ...       ...                  ...         ...  ...
# 725    AK    ALASKA    MATANUSKA-SUSITNA          AK  ...
# 734    AK    ALASKA    MATANUSKA-SUSITNA          AK  ...
# 737    AK    ALASKA  WRANGELL-PETERSBURG          AK  ...
# 746    AK    ALASKA      SKAGWAY-YAKUTAT          AK  ...
# 749    AK    ALASKA    KETCHIKAN GATEWAY          AK  ...
#
#     AirportPositionSource AirportPositionSourceDate AirportElevationSource  \
# 3                     NaN                       NaN                    NaN
# 5                   STATE                  00:00:00                  STATE
# 8                     NaN                       NaN                    NaN
# 15                    NaN                       NaN                    NaN
# 24                  OWNER                  00:00:00                  OWNER
# ..                    ...                       ...                    ...
# 725                 OWNER                  00:00:00                  OWNER
# 734               FAA-EST                  00:00:00                  STATE
# 737                   NaN                       NaN                    NaN
# 746               FAA-EST                  00:00:00                    NaN
# 749                   NaN                       NaN                    NaN
#
#     AirportElevationSourceDate ContractFuelAvailable TransientStorage  \
# 3                          NaN                   NaN              NaN
# 5                     00:00:00                   NaN              NaN
# 8                          NaN                   NaN              TIE
# 15                         NaN                   NaN              NaN
# 24                    00:00:00                   NaN              NaN
# ..                         ...                   ...              ...
# 725                   00:00:00                   NaN              NaN
# 734                   00:00:00                   NaN              TIE
# 737                        NaN                   NaN              NaN
# 746                        NaN                   NaN              TIE
# 749                        NaN                   NaN              NaN
#
#     OtherServices WindIndicator IcaoIdentifier BeaconSchedule2
# 3             NaN             N            NaN             NaN
# 5             NaN             Y            NaN             NaN
# 8             NaN           NaN            NaN             NaN
# 15            NaN             N            NaN             NaN
# 24            NaN             Y            NaN             NaN
# ..            ...           ...            ...             ...
# 725           NaN           NaN            NaN             NaN
# 734          CHTR             Y            NaN             NaN
# 737         CARGO             Y            NaN             NaN
# 746         CARGO           NaN            NaN             NaN
# 749         CARGO             N            NaN             NaN
#
# [138 rows x 103 columns]

# %% [markdown]
# `df_facilities[df_facilities["Type"] == "SEAPLANE BASE"]` can be interpreted as:
#
# > Filter dataframe `df_facilties` conditioning on variable `Type` being strictly equal to `"SEAPLANE BASE"`.
#
# And the table shown above is the answer to Question 2.

# %% [markdown]
# ### Question 3: What are the 5 highest aviation facilities in Alaska?
#
# In this dataset, the `ARPElevation` variable records the elevation of aviation facilities in Alaska in feet. What we will do is to sort the rows of this dataset in reverse based on the value of column `ARPElevation`. This can be done with `sort_values` method of Pandas dataframe:

# %%
df_facilities.sort_values(by = "ARPElevation", ascending = False)
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 584   50739.1*A        AIRPORT      'AA09     3/30/2017    AAL           NONE
# 630  50738.20*A        AIRPORT      '93AK     3/30/2017    AAL           NONE
# 265   50324.6*A        AIRPORT       '4Z5     3/30/2017    AAL           NONE
# 582  50738.01*A        AIRPORT      '2AK7     3/30/2017    AAL           NONE
# 353  50439.18*A        AIRPORT      'AK80     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 183   50196.3*C  SEAPLANE BASE       'ELV     3/30/2017    AAL           NONE
# 516    50680.*C  SEAPLANE BASE       'A23     3/30/2017    AAL           NONE
# 363   50455.6*C  SEAPLANE BASE       '13Z     3/30/2017    AAL           NONE
# 382    50489.*C  SEAPLANE BASE       'MTM     3/30/2017    AAL           NONE
# 628   50773.5*C  SEAPLANE BASE      'AK62     3/30/2017    AAL           NONE
#
#     State StateName               County CountyState  ...  \
# 584    AK    ALASKA    MATANUSKA-SUSITNA          AK  ...
# 630    AK    ALASKA    MATANUSKA-SUSITNA          AK  ...
# 265    AK    ALASKA  SOUTHEAST FAIRBANKS          AK  ...
# 582    AK    ALASKA    MATANUSKA-SUSITNA          AK  ...
# 353    AK    ALASKA    MATANUSKA-SUSITNA          AK  ...
# ..    ...       ...                  ...         ...  ...
# 183    AK    ALASKA      SKAGWAY-YAKUTAT          AK  ...
# 516    AK    ALASKA  WRANGELL-PETERSBURG          AK  ...
# 363    AK    ALASKA    KETCHIKAN GATEWAY          AK  ...
# 382    AK    ALASKA    KETCHIKAN GATEWAY          AK  ...
# 628    AK    ALASKA    KETCHIKAN GATEWAY          AK  ...
#
#     AirportPositionSource AirportPositionSourceDate AirportElevationSource  \
# 584                   NaN                       NaN                    NaN
# 630                 OWNER                  00:00:00                  OWNER
# 265            FAA OE/AAA                  00:00:00             FAA OE/AAA
# 582                   NaN                       NaN                    NaN
# 353                 OWNER                  00:00:00                  OWNER
# ..                    ...                       ...                    ...
# 183                   NaN                       NaN                    NaN
# 516                   NaN                       NaN                    NaN
# 363                   NaN                       NaN                    NaN
# 382                   NaN                       NaN                    NaN
# 628                   NaN                       NaN                    NaN
#
#     AirportElevationSourceDate ContractFuelAvailable TransientStorage  \
# 584                        NaN                   NaN              NaN
# 630                   00:00:00                   NaN              NaN
# 265                   00:00:00                   NaN              NaN
# 582                        NaN                   NaN              NaN
# 353                   00:00:00                   NaN              NaN
# ..                         ...                   ...              ...
# 183                        NaN                   NaN              NaN
# 516                        NaN                   NaN              NaN
# 363                        NaN                   NaN              NaN
# 382                        NaN                   NaN              NaN
# 628                        NaN                   NaN              NaN
#
#     OtherServices WindIndicator IcaoIdentifier BeaconSchedule2
# 584           NaN             Y            NaN             NaN
# 630         CARGO             Y            NaN             NaN
# 265           NaN             Y            NaN             NaN
# 582           NaN           NaN            NaN             NaN
# 353           NaN             Y            NaN             NaN
# ..            ...           ...            ...             ...
# 183           NaN           NaN           PAEL             NaN
# 516         CARGO           NaN            NaN             NaN
# 363           NaN             N            NaN             NaN
# 382         CARGO             Y           PAMM             NaN
# 628         CARGO             N            NaN             NaN
#
# [751 rows x 103 columns]

# %% [markdown]
# When `ascending = True`, the values are arranged from smallest to largest. This means that with `ascending = False`, the values will be arranged from largest to smallest, allowing us to sort the aviation facilities from highest to lowest.
#
# To sort the dataset, you need to know:
#
# *   The name(s) of column(s) to sort by, and
# *   The sorting order.
#
# After sorting the dataset, we'll extract the first five rows which will contain the five highest aviation facilities, thus answering Question 3. This can be done with `head` method of Pandas dataframe.

# %%
df_facilities.sort_values(by = "ARPElevation", ascending = False).head(n = 5)
# Out:
#      SiteNumber     Type LocationID EffectiveDate Region DistrictOffice State  \
# 584   50739.1*A  AIRPORT      'AA09     3/30/2017    AAL           NONE    AK
# 630  50738.20*A  AIRPORT      '93AK     3/30/2017    AAL           NONE    AK
# 265   50324.6*A  AIRPORT       '4Z5     3/30/2017    AAL           NONE    AK
# 582  50738.01*A  AIRPORT      '2AK7     3/30/2017    AAL           NONE    AK
# 353  50439.18*A  AIRPORT      'AK80     3/30/2017    AAL           NONE    AK
#
#     StateName               County CountyState  ... AirportPositionSource  \
# 584    ALASKA    MATANUSKA-SUSITNA          AK  ...                   NaN
# 630    ALASKA    MATANUSKA-SUSITNA          AK  ...                 OWNER
# 265    ALASKA  SOUTHEAST FAIRBANKS          AK  ...            FAA OE/AAA
# 582    ALASKA    MATANUSKA-SUSITNA          AK  ...                   NaN
# 353    ALASKA    MATANUSKA-SUSITNA          AK  ...                 OWNER
#
#     AirportPositionSourceDate AirportElevationSource  \
# 584                       NaN                    NaN
# 630                  00:00:00                  OWNER
# 265                  00:00:00             FAA OE/AAA
# 582                       NaN                    NaN
# 353                  00:00:00                  OWNER
#
#     AirportElevationSourceDate ContractFuelAvailable TransientStorage  \
# 584                        NaN                   NaN              NaN
# 630                   00:00:00                   NaN              NaN
# 265                   00:00:00                   NaN              NaN
# 582                        NaN                   NaN              NaN
# 353                   00:00:00                   NaN              NaN
#
#     OtherServices WindIndicator IcaoIdentifier BeaconSchedule2
# 584           NaN             Y            NaN             NaN
# 630         CARGO             Y            NaN             NaN
# 265           NaN             Y            NaN             NaN
# 582           NaN           NaN            NaN             NaN
# 353           NaN             Y            NaN             NaN
#
# [5 rows x 103 columns]

# %% [markdown]
# The number of rows returned is determined by `n` parameter of method `head`. The result of the above code is the answer to Question 3.

# %% [markdown]
# ### Question 4: What is the average elevation of aviation facilities?
#
# In this dataset, we know that `ARPElevation` tells us the elevation of aviation facilities in Alaska. So how do we find the average or, in other words, the mean of those numbers?
#
# Pandas has a built in function `mean()` that we can use to easily calculate the average of that column.
#
# Let's take our dataframe and apply that function!

# %%
df_facilities["ARPElevation"].mean()
# Out:
# 425.93209054593876

# %% [markdown]
# As we can see from that result, the average elevation of aviation facilities is almost 426 ft.

# %% [markdown]
# ### Question 5: What are the highest and lowest elevation values of the aviation facilities?
#
# How do we go about solving this question? Well, similar to the previous question, Pandas has built-in functions that help us find the maximum (largest) and minimum (lowest) values in a column. These functions are `max()` and `min()`, respectively.
#
# Given the process we took to find the average elevation in the last question, try finding the highest and lowest elevation on your own!
#
# #### Task A: Find the highest elevation value

# %%
# Type your solution here

# %% [markdown]
# <details><summary>Click here for a hint:</summary>
# Recall what we did to find the mean:
#
# <code>df_facilities\["ARPElevation"].mean()</code>
#
# What should be changed to find the maximum value?
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution:</summary>
# Your code should look like the following:
#
# <code>df_facilities\["ARPElevation"].max()</code>
#
# </details>

# %% [markdown]
# #### Task B: Find the lowest elevation value

# %%
# Type your code here

# %% [markdown]
# <details><summary>Click here for a hint:</summary>
# Remember what we did to find the max:
#
# <code>df_facilities\["ARPElevation"].max()</code>
#
# What should be changed to find the minimum value?
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution:</summary>
# Your code should look like the following:
#
# <code>df_facilities\["ARPElevation"].min()</code>
#
# </details>

# %% [markdown]
# Turns out the maximum and minimum values of elevation are 3984 ft and 0 ft, respectively. Interesting, right?

# %% [markdown]
# Pandas is much more powerful than answer above three simple questions. The three examples I showcased are just three commonly used ones. If you would like to learn more about data science tools, consider taking [Introduction to Data Science](https://cognitiveclass.ai/courses/data-science-101/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkQuickLabsanalysingspreadsheetdatawithpython28639550-2022-01-01), a course proudly provided by IBM!

# %% [markdown]
# ## Exercise 5: Write to `xlsx` Files!
#
# After getting the results we want, we often want to save those results on our computer for future use. We can save a dataframe to our computer directly in Python!
#
# For example, let's say we want to store the answer to Question 1 in a file called `seaplane.xlsx`.
#
# First, let's save the result to a local variable:

# %%
df_seaplane = df_facilities[df_facilities["Type"] == "SEAPLANE BASE"]

# %% [markdown]
# Now, the answer to Question 1 is saved in the variable `df_seaplane`.
#
# To save a dataframe in `xlsx` format, we can use the `to_excel` method. This will write the contents of the object, `df_seaplane`, into an Excel `xlsx` file.

# %%
df_seaplane.to_excel("./seaplane.xlsx")

# %% [markdown]
# Congratulations! You've successfully saved the table from Question 1 to a file! If you want to see the file you saved, check the file panel on the left.
#
# ![File Panel](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/analysing-spreadsheet-data-with-python/images/File_Panel.png)
#
# Now that you know how to analyze spreadsheet data with Python, go try it out on your own spreadsheet!
#
# If you're interested in learning more about analyzing data with Python, consider taking [Data Analysis with Python](https://cognitiveclass.ai/courses/data-analysis-python?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkQuickLabsanalysingspreadsheetdatawithpython28639550-2022-01-01) to explore even more functions provided by Pandas!

# %% [markdown]
# # Author(s)
#
# [Weiqing Wang](https://www.linkedin.com/in/weiqing-wang-641640133/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkQuickLabsanalysingspreadsheetdatawithpython28639550-2022-01-01)
#
# Weiqing is a Data Scientist intern at IBM Canada Ltd. Weiqing holds an Honours Bachelor of Science from the University of Toronto with two specialist degrees, respectively in computer science and statistical sciences. He is presently working towards a graduate degree in computer science at the University of Toronto.
#
# ## Other contributors
#
# Kathy An, Yasmine Hemmati
#
# # Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By   | Change Description       |
# | ----------------- | ------- | ------------ | ------------------------ |
# | 2021-08-10        | 1.0     | Weiqing Wang | Initial Version Created. |
# |                   |         |              |                          |
# |                   |         |              |                          |
#
# © IBM Corporation 2021. All rights reserved.
